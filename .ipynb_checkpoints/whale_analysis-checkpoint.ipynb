# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
whale_returns_df = pd.read_csv(Path('Resources/whale_returns.csv'),index_col='Date',parse_dates=True,infer_datetime_format=True)
# Display a sample of the data
whale_returns_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
print(f'There are {whale_returns_df.isnull().sum().sum()} nulls in the Whale returns data')
# Out:
# There are 4 nulls in the Whale returns data

# %%
# Drop nulls
whale_returns_df.dropna(inplace=True)
# Check again for nulls
print(f'There are {whale_returns_df.isnull().sum().sum()} nulls in the Whale returns data')
# Out:
# There are 0 nulls in the Whale returns data

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algo_returns_df = pd.read_csv(Path('Resources/algo_returns.csv'),index_col='Date',parse_dates=True,infer_datetime_format=True)
# Display a sample of the data
algo_returns_df.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Count nulls
print(f'There are {algo_returns_df.isnull().sum().sum()} nulls in the Algo returns data')
# Out:
# There are 6 nulls in the Algo returns data

# %%
# Drop nulls
algo_returns_df.dropna(inplace=True)
# Check again for nulls
print(f'There are {algo_returns_df.isnull().sum().sum()} nulls in the Algo returns data')
# Out:
# There are 0 nulls in the Algo returns data

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
sp500_close_df = pd.read_csv(Path('Resources/sp500_history.csv'),index_col='Date',parse_dates=True,infer_datetime_format=True)
# Sort the data for proper analysis later
sp500_close_df.sort_index(inplace=True)
# Display a sample of the data
sp500_close_df.head()
# Out:
#                Close
# Date
# 2012-10-01  $1444.49
# 2012-10-02  $1445.75
# 2012-10-03  $1450.99
# 2012-10-04  $1461.40
# 2012-10-05  $1460.93

# %%
# Check Data Types
sp500_close_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Remove the $ sign in order to convert to float
sp500_close_df['Close'] = sp500_close_df['Close'].str.replace('$','')
# Fix Data Types
sp500_close_df = sp500_close_df.astype({'Close':'float'})
# Check again data types
sp500_close_df.dtypes
# Out:
# /var/folders/l_/z3f0tw616952x5ddvbpxjdhr0000gn/T/ipykernel_6057/4087052320.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   sp500_close_df['Close'] = sp500_close_df['Close'].str.replace('$','')
# Close    float64
# dtype: object

# %%
# Calculate Daily Returns
sp500_returns_df = sp500_close_df.pct_change()
sp500_returns_df.head()
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322

# %%
# Drop nulls
sp500_returns_df.dropna(inplace=True)
# Check again for nulls
print(f'There are {sp500_returns_df.isnull().sum().sum()} nulls in the SP500 returns data')
# Out:
# There are 0 nulls in the SP500 returns data

# %%
# Rename `Close` Column to be specific to this portfolio.
sp500_returns_df.columns = ['S&P500']
sp500_returns_df.head()
# Out:
#               S&P500
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.
combined_returns_df = pd.concat([whale_returns_df,algo_returns_df,sp500_returns_df],axis='columns',join='inner')
combined_returns_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2    S&P500
# Date
# 2015-03-03 -0.000949 -0.004539
# 2015-03-04  0.002416 -0.004389
# 2015-03-05  0.004323  0.001196
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
combined_returns_df.plot(figsize=(15,10),title='Cumulative returns of Whale, Algo, and S&P500 portfolios')
# Out:
# <Axes: title={'center': 'Cumulative returns of Whale, Algo, and S&P500 portfolios'}, xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
combined_cum_df = (1+combined_returns_df).cumprod()
# Plot cumulative returns
combined_cum_df.plot(figsize=(15,10),title='Cumulative returns of Whale, Algo, and S&P500 portfolios')
# Out:
# <Axes: title={'center': 'Cumulative returns of Whale, Algo, and S&P500 portfolios'}, xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
combined_returns_df.boxplot(figsize=(20,5),fontsize=10)
plt.title('Box plot of Whale, Algo, and S&P500 portfolios')
# Out:
# Text(0.5, 1.0, 'Box plot of Whale, Algo, and S&P500 portfolios')

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
combined_std = combined_returns_df.std()
combined_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.007895
# PAULSON & CO.INC.              0.007023
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007620
# Algo 2                         0.008342
# S&P500                         0.008554
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Calculate  the daily standard deviation of S&P 500
sp500_std = combined_returns_df['S&P500'].std()
# Determine which portfolios are riskier than the S&P 500
risky_port = []
for col in combined_returns_df.columns[:-1]:
    if combined_returns_df[col].std() > sp500_std:
        risky_port.append(col)
# Output the list of risky portfolios
if not risky_port:
    print('None of the portfolios are riskier than the S&P500')
else:
    print(f'The following portfolios are riskier than the S&P500: {risky_port}')
# Out:
# The following portfolios are riskier than the S&P500: ['TIGER GLOBAL MANAGEMENT LLC', 'BERKSHIRE HATHAWAY INC']

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
combined_std_annual = combined_std * np.sqrt(252)
combined_std_annual
# Out:
# SOROS FUND MANAGEMENT LLC      0.125335
# PAULSON & CO.INC.              0.111488
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# BERKSHIRE HATHAWAY INC         0.205077
# Algo 1                         0.120967
# Algo 2                         0.132430
# S&P500                         0.135786
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
combined_rolling_21_std = combined_returns_df.rolling(21).std()
# Plot the rolling standard deviation
combined_rolling_21_std.plot(figsize=(15,10),title='21-day rolling std of Whale, Algo, and S&P500 portfolios')
# Out:
# <Axes: title={'center': '21-day rolling std of Whale, Algo, and S&P500 portfolios'}, xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
combined_corr = combined_returns_df.corr()
display(combined_corr)
# Display de correlation matrix
sns.heatmap(combined_corr,vmin=-1,vmax=1)
plt.title('Correlation matrix of Whale, Algo, and S&P500 portfolios')
print('Algo2 is the most highly correlated to S&P500, and given that its cumulative returns are lower than those for S&P500 and its std is only slightly less than S&P500, Algo2 is a strong candidate to be dropped out of the portfolio mix if we want to diversify and beat S&P500 (the market)\n')
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699914
# PAULSON & CO.INC.                             0.699914            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561243            0.434479
# BERKSHIRE HATHAWAY INC                        0.754360            0.545623
# Algo 1                                        0.321211            0.268840
# Algo 2                                        0.826873            0.678152
# S&P500                                        0.837864            0.669732
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561243
# PAULSON & CO.INC.                               0.434479
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424423
# Algo 1                                          0.164387
# ...

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of a single portfolio (applying a rolling 60 day window, per the instructions)
algo1_rolling_60_cov = combined_returns_df['Algo 1'].rolling(60).cov(combined_returns_df['S&P500'])
# Calculate variance of S&P 500
sp500_rolling_60_var = combined_returns_df['S&P500'].rolling(60).var()
# Computing beta
algo1_rolling_60_beta = algo1_rolling_60_cov/sp500_rolling_60_var
# Plot beta trend
algo1_rolling_60_beta.plot(figsize=(15,10),title='60-day rolling beta of Algo1 portfolio')
# Out:
# <Axes: title={'center': '60-day rolling beta of Algo1 portfolio'}, xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half life for each portfolio, using standard deviation (`std`) as the metric of interest.

# %%
# Use `ewm` to calculate the rolling window
combined_rolling_21_ewm_std = combined_returns_df.ewm(halflife=21).std()
combined_rolling_21_ewm_std.plot(figsize=(15,10),title='Rolling std with exponentially-weighted moving averages')
# Out:
# <Axes: title={'center': 'Rolling std with exponentially-weighted moving averages'}, xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
combined_sharpe_ratios = ((combined_returns_df.mean()-combined_returns_df['S&P500'].mean()) * 252) / (combined_std_annual)
# Remove the S&P500 column from the dataframe
combined_sharpe_ratios.drop('S&P500',inplace=True)
# Display the results
combined_sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC     -0.345907
# PAULSON & CO.INC.             -1.273125
# TIGER GLOBAL MANAGEMENT LLC   -0.630067
# BERKSHIRE HATHAWAY INC         0.192576
# Algo 1                         0.650964
# Algo 2                        -0.163336
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
combined_sharpe_ratios.plot(kind='bar',figsize=(15,10),title='Sharpe ratios of Whale and Algo portfolios')
# Out:
# <Axes: title={'center': 'Sharpe ratios of Whale and Algo portfolios'}>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# Algo1 only (not Algo2, as covered above) outperforms in a risk-adjusted sense both the market and the wales portfolios in the time period covered, given its significantly high Sharpe ratio compared to that of the other portfolios.

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Reading data from 1st stock
delta_df = pd.read_csv(Path('Resources/DAL_historical.csv'),index_col='Date',parse_dates=True,infer_datetime_format=True)
# Sort the data
delta_df.sort_index(inplace=True)
# Display a sample of the data
delta_df.head()
# Out:
#                      Close
# Date
# 2015-01-02 16:00:00  49.18
# 2015-01-05 16:00:00  48.36
# 2015-01-06 16:00:00  47.22
# 2015-01-07 16:00:00  46.97
# 2015-01-08 16:00:00  48.19

# %%
# Reading data from 2nd stock
mmm_df = pd.read_csv(Path('Resources/MMM_historical.csv'),index_col='Date',parse_dates=True,infer_datetime_format=True)
# Sort the data
mmm_df.sort_index(inplace=True)
# Display a sample of the data
mmm_df.head()
# Out:
#                       Close
# Date
# 2015-01-02 16:00:00  164.06
# 2015-01-05 16:00:00  160.36
# 2015-01-06 16:00:00  158.65
# 2015-01-07 16:00:00  159.80
# 2015-01-08 16:00:00  163.63

# %%
# Reading data from 3rd stock
tesla_df = pd.read_csv(Path('Resources/TSLA_historical.csv'),index_col='Date',parse_dates=True,infer_datetime_format=True)
# Sort the data
tesla_df.sort_index(inplace=True)
# Display a sample of the data
tesla_df.head()
# Out:
#                      Close
# Date
# 2015-01-02 16:00:00  14.62
# 2015-01-05 16:00:00  14.01
# 2015-01-06 16:00:00  14.09
# 2015-01-07 16:00:00  14.06
# 2015-01-08 16:00:00  14.04

# %%
# Reading data from 4th stock
exxon_df = pd.read_csv(Path('Resources/XOM_historical.csv'),index_col='Date',parse_dates=True,infer_datetime_format=True)
# Sort the data
exxon_df.sort_index(inplace=True)
# Display a sample of the data
exxon_df.head()
# Out:
#                      Close
# Date
# 2015-01-02 16:00:00  92.83
# 2015-01-05 16:00:00  90.29
# 2015-01-06 16:00:00  89.81
# 2015-01-07 16:00:00  90.72
# 2015-01-08 16:00:00  92.23

# %%
# Combine all stocks in a single DataFrame
my_port = pd.concat([delta_df,mmm_df,tesla_df,exxon_df],axis='columns',join='inner')
# Set the column names to the portfolio stocks
my_port.columns = ['Delta','3M','Tesla','Exxon']
# Display a sample of the data
my_port.head()
# Out:
#                      Delta      3M  Tesla  Exxon
# Date
# 2015-01-02 16:00:00  49.18  164.06  14.62  92.83
# 2015-01-05 16:00:00  48.36  160.36  14.01  90.29
# 2015-01-06 16:00:00  47.22  158.65  14.09  89.81
# 2015-01-07 16:00:00  46.97  159.80  14.06  90.72
# 2015-01-08 16:00:00  48.19  163.63  14.04  92.23

# %%
# Reset Date index
my_port.reset_index(inplace=True)
my_port['Date'] = pd.to_datetime(my_port['Date'].dt.strftime('%Y-%m-%d'))
my_port.set_index('Date',inplace=True)
# Display a sample of the data
my_port.head()
# Out:
#             Delta      3M  Tesla  Exxon
# Date
# 2015-01-02  49.18  164.06  14.62  92.83
# 2015-01-05  48.36  160.36  14.01  90.29
# 2015-01-06  47.22  158.65  14.09  89.81
# 2015-01-07  46.97  159.80  14.06  90.72
# 2015-01-08  48.19  163.63  14.04  92.23

# %%
# Reorganize portfolio data by having a column per symbol
# (I didn't have to perform this step, as I already provided column headers after combining the tickers into a single portfolio)

# %%
# Calculate daily returns
my_port = my_port.pct_change()
# Drop NAs
my_port.dropna(inplace=True)
# Display sample data
my_port.head()
# Out:
#                Delta        3M     Tesla     Exxon
# Date
# 2015-01-05 -0.016673 -0.022553 -0.041724 -0.027362
# 2015-01-06 -0.023573 -0.010664  0.005710 -0.005316
# 2015-01-07 -0.005294  0.007249 -0.002129  0.010133
# 2015-01-08  0.025974  0.023967 -0.001422  0.016645
# 2015-01-09 -0.027184 -0.012284 -0.018519 -0.001410

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/4, 1/4, 1/4, 1/4]
# Calculate portfolio return
my_port_returns = pd.DataFrame(my_port.dot(weights))
# Set the column name
my_port_returns.columns = ['My Portfolio']
# Display sample data
my_port_returns.head()
# Out:
#             My Portfolio
# Date
# 2015-01-05     -0.027078
# 2015-01-06     -0.008461
# 2015-01-07      0.002489
# 2015-01-08      0.016291
# 2015-01-09     -0.014849

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
combined_returns_df = pd.concat([combined_returns_df,my_port_returns],axis='columns',join='inner')
combined_returns_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2    S&P500  My Portfolio
# Date
# 2015-03-03 -0.000949 -0.004539      0.000345
# 2015-03-04  0.002416 -0.004389     -0.002586
# ...

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
# Check for nulls
print(f'There are {combined_returns_df.isnull().sum().sum()} nulls in the combined returns data')
# Out:
# There are 0 nulls in the combined returns data

# %% [markdown]
# There are no NAs in the combined data since we used an inner join to concatenate my portfolio, so no need to drop NAs

# %%
# Calculate cumulative returns of all portfolios
combined_cum_df = (1+combined_returns_df).cumprod()
# Plot cumulative returns
combined_cum_df.plot(figsize=(15,10),title='Cumulative returns of Whale, Algo, S&P500, and \'My Portfolio\' portfolios')
# Out:
# <Axes: title={'center': "Cumulative returns of Whale, Algo, S&P500, and 'My Portfolio' portfolios"}, xlabel='Date'>

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
combined_std = combined_returns_df.std()
combined_std_annual = combined_std * np.sqrt(252)
combined_std_annual
# Out:
# SOROS FUND MANAGEMENT LLC      0.125335
# PAULSON & CO.INC.              0.111488
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# BERKSHIRE HATHAWAY INC         0.205077
# Algo 1                         0.120967
# Algo 2                         0.132430
# S&P500                         0.135786
# My Portfolio                   0.188004
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
combined_rolling_21_std = combined_returns_df.rolling(21).std()
# Plot rolling standard deviation
combined_rolling_21_std.plot(figsize=(15,10),title='21-day rolling std of Whale, Algo, S&P500, and \'My portfolio\' portfolios')
# Out:
# <Axes: title={'center': "21-day rolling std of Whale, Algo, S&P500, and 'My portfolio' portfolios"}, xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
combined_corr = combined_returns_df.corr()
display(combined_corr)
# Display de correlation matrix
sns.heatmap(combined_corr,vmin=-1,vmax=1)
plt.title('Correlation matrix of Whale, Algo, S&P500, and \'My portfolio\' portfolios')
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699914
# PAULSON & CO.INC.                             0.699914            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561243            0.434479
# BERKSHIRE HATHAWAY INC                        0.754360            0.545623
# Algo 1                                        0.321211            0.268840
# Algo 2                                        0.826873            0.678152
# S&P500                                        0.837864            0.669732
# My Portfolio                                  0.668218            0.498169
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561243
# PAULSON & CO.INC.                               0.434479
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424423
# ...

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta
my_port_rolling_60_cov = combined_returns_df['My Portfolio'].rolling(60).cov(combined_returns_df['S&P500'])
# Calculate variance of S&P 500. It should not have changed from earlier, but being extra accurate just in case
sp500_rolling_60_var = combined_returns_df['S&P500'].rolling(60).var()
# Computing beta
my_port_rolling_60_beta = my_port_rolling_60_cov/sp500_rolling_60_var
# Plot beta trend
my_port_rolling_60_beta.plot(figsize=(15,10),title='60-day rolling beta of My Portfolio')
# Out:
# <Axes: title={'center': '60-day rolling beta of My Portfolio'}, xlabel='Date'>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualized Sharpe Ratios
combined_sharpe_ratios = ((combined_returns_df.mean()-combined_returns_df['S&P500'].mean()) * 252) / (combined_std_annual)
# Remove the S&P500 column from the dataframe
combined_sharpe_ratios.drop('S&P500',inplace=True)
# Display the results
combined_sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC     -0.345907
# PAULSON & CO.INC.             -1.273125
# TIGER GLOBAL MANAGEMENT LLC   -0.630067
# BERKSHIRE HATHAWAY INC         0.192576
# Algo 1                         0.650964
# Algo 2                        -0.163336
# My Portfolio                  -0.000742
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
combined_sharpe_ratios.plot(kind='bar',figsize=(15,10),title='Sharpe ratios of Whale, Algo, and \'My Portfolio\' portfolios')
# Out:
# <Axes: title={'center': "Sharpe ratios of Whale, Algo, and 'My Portfolio' portfolios"}>

# %% [markdown]
# ### How does your portfolio do?
#
# During the period covered (Jan 2015 to July 2019) my portfolio slightly underperformed the market, additionally, its volatility was considerably higher than that of the market, both are highlighted by the slightly negative and infinitely small sharpe ratio result for my portfolio.<br>
# As I reevaluate my portfolio, I should analyze the correlation with each of its assets, to include a variety that are not too closely correlated, which would help diversify the portfolio.
